# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../output/energy_history.csv")

# drop all columns that start with "User"
df = df.drop(columns=df.filter(regex="^User").columns)

print(df.head())
# Out:
#    Base Station 0  Base Station 1  Base Station 2  Base Station 3  HAPS 0  \
# 0            50.0            50.0            50.0            50.0    50.0
# 1            50.0            50.0            50.0            50.0    50.0
# 2            50.0            50.0            50.0            50.0    50.0
# 3            50.0            50.0            50.0            50.0    50.0
# 4            50.0            50.0            50.0            50.0    50.0
#
#    LEO 0
# 0   50.0
# 1   50.0
# 2   50.0
# 3   50.0
# 4   50.0

# %%
df.plot(kind="line", figsize=(10, 5))
plt.show()

# %%
df = df["HAPS 0"]

df.plot(kind="line", figsize=(10, 5))
plt.show()

# %%
# print cumulative sum
print(df.cumsum())

cum_df = df.cumsum()

cum_df.plot(kind="line", figsize=(10, 5))
plt.show()
# Out:
# 0           50.000000
# 1          100.000000
# 2          150.000000
# 3          200.000000
# 4          250.000000
#             ...
# 2996    100030.786261
# 2997    100030.786261
# 2998    100030.786261
# 2999    100030.786261
# 3000    100030.786261
# Name: HAPS 0, Length: 3001, dtype: float64
